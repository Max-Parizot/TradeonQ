# %%
#this code block is to dynamically build Q until convergence
#it can be put into a function and all values of interest can be returned. However! You want to store everything to see the result at it progresses.
import dynamic_Q as Q
import requests
import numpy as np
from scipy.linalg import expm
from skopt import BayesSearchCV
from skopt.space import Integer
from datetime import datetime, timedelta
import pandas as pd
import numpy as np
from scipy.signal import convolve
import time


# Initialize Data as a DataFrame
Data = pd.DataFrame({'t': [], 'S': [], 'I': [], 'MOBid':[], 'MOAsk': []})
inhomogeneity_convergence = []
Qt_old = np.array([])
#initialize parameters
n=5
N=20
counter = 0
tolerance = 0.0001 #Convergence Tolerance

print('starting while loop')
while True:
    start_time = time.time()
    ask_prices, ask_volumes, ask_timestamps, bid_prices, bid_volumes, bid_timestamps, mid_price,ImbalanceRatio = Q.get_LOB(requests.get('https://api.kraken.com/0/public/Depth?pair=XBTUSD'))
    #print('got data', counter)
    
    # Create a new row
    new_row = {'t': bid_timestamps[0], 'S': mid_price, 'I': ImbalanceRatio, 'MOBid':bid_prices[0], 'MOAsk': ask_prices[0]}
    # Append the new row to the DataFrame
    Data=pd.concat([Data, pd.DataFrame(new_row, index=[0])], ignore_index=True)

    # Increment the counter
    counter += 1

    # Every 25 iterations (every 5 seconds), run the Q function
    if counter % 25 == 0:
        print('running Q', counter)
        Qt= Q.make_Q(Data, n, N)
        if Qt_old.shape == Qt.shape and not np.isnan(Qt).any():
            Q_diff=Qt_old - Qt
            Inhomogeneity= np.sum ((Qt_old > 0.5) & (Qt < 0.5) | (Qt_old < 0.5) & (Qt > 0.5)) #trading inefficiencies, which result from indices (market states) where one matrix gives a trading cue (probability value > 0.5) and the other does not.
            inhomogeneity_convergence.append(Inhomogeneity) #store data for future plotting
            print("Qt no longer has NaN values.",Inhomogeneity, 'inefficiencies')
            if np.max(np.abs(Q_diff)) < tolerance:
                print("Q has converged in {} values.".format(counter))
                break
        else:
            print('Qt_old',Qt_old.shape,'and Qt', Qt.shape, 'have NaN values. Qt_old is now Qt.')
        Qt_old = Qt
    
    end_time = time.time()
    if end_time - start_time <.33 :
        print('sleeping. You have fast wifi! Waiting for', .33 - (end_time - start_time))
        time.sleep(.33 - (end_time - start_time))
# Out:
# starting while loop
# running Q 25
# Qt_old (0,) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# c:\Users\Maxparizot\Documents\GitHub\TradeonQ\Code_3\dynamic_Q.py:84: RuntimeWarning: invalid value encountered in divide
#   G = C / H
# running Q 50
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 75
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# c:\Users\Maxparizot\Documents\GitHub\TradeonQ\Code_3\dynamic_Q.py:84: RuntimeWarning: divide by zero encountered in divide
#   G = C / H
# running Q 100
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 125
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 150
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 175
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 200
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 225
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 250
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 275
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 300
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 325
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 350
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 375
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 400
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 425
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 450
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 475
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 500
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 525
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 550
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 575
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 600
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 625
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 650
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 675
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 700
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 725
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 750
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 775
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 800
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 825
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 850
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 875
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 900
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 925
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 950
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 975
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1000
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1025
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1050
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1075
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1100
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1125
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1150
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1175
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1200
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1225
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1250
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1275
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1300
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1325
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1350
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1375
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1400
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1425
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1450
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1475
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1500
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1525
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1550
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1575
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1600
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1625
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1650
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1675
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1700
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1725
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1750
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1775
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1800
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1825
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1850
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1875
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1900
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1925
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1950
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 1975
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 2000
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 2025
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 2050
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 2075
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 2100
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 2125
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 2150
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 2175
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 2200
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 2225
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 2250
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 2275
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 2300
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 2325
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 2350
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 2375
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 2400
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 2425
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 2450
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 2475
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 2500
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 2525
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 2550
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2575
# Qt no longer has NaN values. 1 inefficiencies
# running Q 2600
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2625
# Qt no longer has NaN values. 5 inefficiencies
# running Q 2650
# Qt no longer has NaN values. 1 inefficiencies
# running Q 2675
# Qt no longer has NaN values. 1 inefficiencies
# running Q 2700
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2725
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2750
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2775
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2800
# Qt no longer has NaN values. 1 inefficiencies
# running Q 2825
# Qt no longer has NaN values. 2 inefficiencies
# running Q 2850
# Qt no longer has NaN values. 2 inefficiencies
# running Q 2875
# Qt no longer has NaN values. 2 inefficiencies
# running Q 2900
# Qt no longer has NaN values. 2 inefficiencies
# running Q 2925
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2950
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2975
# Qt no longer has NaN values. 2 inefficiencies
# running Q 3000
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3025
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3050
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3075
# Qt no longer has NaN values. 5 inefficiencies
# running Q 3100
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3125
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3150
# Qt no longer has NaN values. 12 inefficiencies
# running Q 3175
# Qt no longer has NaN values. 12 inefficiencies
# running Q 3200
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3225
# Qt no longer has NaN values. 12 inefficiencies
# running Q 3250
# Qt no longer has NaN values. 3 inefficiencies
# running Q 3275
# Qt no longer has NaN values. 9 inefficiencies
# running Q 3300
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3325
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3350
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3375
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3400
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3425
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3450
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3475
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3500
# Qt no longer has NaN values. 4 inefficiencies
# running Q 3525
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3550
# Qt no longer has NaN values. 2 inefficiencies
# running Q 3575
# Qt no longer has NaN values. 2 inefficiencies
# running Q 3600
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3625
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3650
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3675
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3700
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3725
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3750
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3775
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3800
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3825
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3850
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3875
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3900
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3925
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3950
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3975
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4000
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4025
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4050
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4075
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4100
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4125
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4150
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4175
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4200
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4225
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4250
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4275
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4300
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4325
# Qt no longer has NaN values. 6 inefficiencies
# running Q 4350
# Qt no longer has NaN values. 1 inefficiencies
# running Q 4375
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4400
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4425
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4450
# Qt no longer has NaN values. 3 inefficiencies
# running Q 4475
# Qt no longer has NaN values. 1 inefficiencies
# running Q 4500
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4525
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4550
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4575
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4600
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4625
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4650
# Qt no longer has NaN values. 1 inefficiencies
# running Q 4675
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4700
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4725
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4750
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4775
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4800
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4825
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4850
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4875
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4900
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4925
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4950
# Qt no longer has NaN values. 5 inefficiencies
# running Q 4975
# Qt no longer has NaN values. 2 inefficiencies
# running Q 5000
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5025
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5050
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5075
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5100
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5125
# Qt no longer has NaN values. 6 inefficiencies
# running Q 5150
# Qt no longer has NaN values. 5 inefficiencies
# running Q 5175
# Qt no longer has NaN values. 1 inefficiencies
# running Q 5200
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5225
# Qt no longer has NaN values. 1 inefficiencies
# running Q 5250
# Qt no longer has NaN values. 1 inefficiencies
# running Q 5275
# Qt no longer has NaN values. 3 inefficiencies
# running Q 5300
# Qt no longer has NaN values. 2 inefficiencies
# running Q 5325
# Qt no longer has NaN values. 11 inefficiencies
# running Q 5350
# Qt no longer has NaN values. 1 inefficiencies
# running Q 5375
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5400
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5425
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5450
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5475
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5500
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5525
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5550
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5575
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5600
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5625
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5650
# Qt no longer has NaN values. 1 inefficiencies
# running Q 5675
# Qt no longer has NaN values. 1 inefficiencies
# running Q 5700
# Qt no longer has NaN values. 1 inefficiencies
# running Q 5725
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5750
# Qt no longer has NaN values. 3 inefficiencies
# running Q 5775
# Qt no longer has NaN values. 2 inefficiencies
# running Q 5800
# Qt no longer has NaN values. 1 inefficiencies
# running Q 5825
# Qt no longer has NaN values. 1 inefficiencies
# running Q 5850
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5875
# Qt no longer has NaN values. 2 inefficiencies
# running Q 5900
# Qt no longer has NaN values. 3 inefficiencies
# running Q 5925
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5950
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5975
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6000
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6025
# Qt no longer has NaN values. 1 inefficiencies
# running Q 6050
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6075
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6100
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6125
# Qt no longer has NaN values. 1 inefficiencies
# running Q 6150
# Qt no longer has NaN values. 2 inefficiencies
# running Q 6175
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6200
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6225
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6250
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6275
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6300
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6325
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6350
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6375
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6400
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6425
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6450
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6475
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6500
# Qt no longer has NaN values. 9 inefficiencies
# running Q 6525
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6550
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6575
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6600
# Qt no longer has NaN values. 3 inefficiencies
# running Q 6625
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6650
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6675
# Qt no longer has NaN values. 3 inefficiencies
# running Q 6700
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6725
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6750
# Qt no longer has NaN values. 1 inefficiencies
# running Q 6775
# Qt no longer has NaN values. 2 inefficiencies
# running Q 6800
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6825
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6850
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6875
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6900
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6925
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6950
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6975
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7000
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7025
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7050
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7075
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7100
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7125
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7150
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7175
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7200
# Qt no longer has NaN values. 3 inefficiencies
# running Q 7225
# Qt no longer has NaN values. 3 inefficiencies
# running Q 7250
# Qt no longer has NaN values. 1 inefficiencies
# running Q 7275
# Qt no longer has NaN values. 2 inefficiencies
# running Q 7300
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7325
# Qt no longer has NaN values. 1 inefficiencies
# running Q 7350
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7375
# Qt no longer has NaN values. 1 inefficiencies
# running Q 7400
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7425
# Qt no longer has NaN values. 4 inefficiencies
# running Q 7450
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7475
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7500
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7525
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7550
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7575
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7600
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7625
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7650
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7675
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7700
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7725
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7750
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7775
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7800
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7825
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7850
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7875
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7900
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7925
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7950
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7975
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8000
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8025
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8050
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8075
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8100
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8125
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8150
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8175
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8200
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8225
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8250
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8275
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8300
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8325
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8350
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8375
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8400
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8425
# Qt no longer has NaN values. 1 inefficiencies
# running Q 8450
# Qt no longer has NaN values. 4 inefficiencies
# running Q 8475
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8500
# Qt no longer has NaN values. 3 inefficiencies
# running Q 8525
# Qt no longer has NaN values. 4 inefficiencies
# running Q 8550
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8575
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8600
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8625
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8650
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8675
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8700
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8725
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8750
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8775
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8800
# Qt no longer has NaN values. 2 inefficiencies
# running Q 8825
# Qt no longer has NaN values. 1 inefficiencies
# running Q 8850
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8875
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8900
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8925
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8950
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8975
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9000
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9025
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9050
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9075
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9100
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9125
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9150
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9175
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9200
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9225
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9250
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9275
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9300
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9325
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9350
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9375
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9400
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9425
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9450
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9475
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9500
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9525
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9550
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9575
# Qt no longer has NaN values. 1 inefficiencies
# running Q 9600
# Qt no longer has NaN values. 1 inefficiencies
# running Q 9625
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9650
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9675
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9700
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9725
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9750
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9775
# Qt no longer has NaN values. 1 inefficiencies
# running Q 9800
# Qt no longer has NaN values. 3 inefficiencies
# running Q 9825
# Qt no longer has NaN values. 2 inefficiencies
# running Q 9850
# Qt no longer has NaN values. 0 inefficiencies
# running Q 9875
# Qt no longer has NaN values. 1 inefficiencies
# running Q 9900
# Qt no longer has NaN values. 1 inefficiencies
# running Q 9925
# Qt no longer has NaN values. 3 inefficiencies
# running Q 9950
# Qt no longer has NaN values. 1 inefficiencies
# running Q 9975
# Qt no longer has NaN values. 3 inefficiencies
# running Q 10000
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10025
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10050
# Qt no longer has NaN values. 2 inefficiencies
# running Q 10075
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10100
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10125
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10150
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10175
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10200
# Qt no longer has NaN values. 3 inefficiencies
# running Q 10225
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10250
# Qt no longer has NaN values. 2 inefficiencies
# running Q 10275
# Qt no longer has NaN values. 4 inefficiencies
# running Q 10300
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10325
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10350
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10375
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10400
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10425
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10450
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10475
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10500
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10525
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10550
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10575
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10600
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10625
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10650
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10675
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10700
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10725
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10750
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10775
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10800
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10825
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10850
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10875
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10900
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10925
# Qt no longer has NaN values. 1 inefficiencies
# running Q 10950
# Qt no longer has NaN values. 0 inefficiencies
# running Q 10975
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11000
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11025
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11050
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11075
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11100
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11125
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11150
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11175
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11200
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11225
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11250
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11275
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11300
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11325
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11350
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11375
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11400
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11425
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11450
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11475
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11500
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11525
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11550
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11575
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11600
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11625
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11650
# Qt no longer has NaN values. 1 inefficiencies
# running Q 11675
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11700
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11725
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11750
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11775
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11800
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11825
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11850
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11875
# Qt no longer has NaN values. 2 inefficiencies
# running Q 11900
# Qt no longer has NaN values. 1 inefficiencies
# running Q 11925
# Qt no longer has NaN values. 3 inefficiencies
# running Q 11950
# Qt no longer has NaN values. 0 inefficiencies
# running Q 11975
# Qt no longer has NaN values. 0 inefficiencies
# running Q 12000
# Qt no longer has NaN values. 6 inefficiencies
# running Q 12025
# Qt no longer has NaN values. 2 inefficiencies
# running Q 12050
# Qt no longer has NaN values. 0 inefficiencies
# running Q 12075
# Qt no longer has NaN values. 0 inefficiencies
# running Q 12100
# Qt no longer has NaN values. 0 inefficiencies
# running Q 12125
# Qt no longer has NaN values. 0 inefficiencies
# running Q 12150
# Qt no longer has NaN values. 4 inefficiencies
# running Q 12175
# Qt no longer has NaN values. 0 inefficiencies
# running Q 12200
# Qt no longer has NaN values. 2 inefficiencies
# running Q 12225
# Qt no longer has NaN values. 0 inefficiencies
# running Q 12250
# Qt no longer has NaN values. 3 inefficiencies
# running Q 12275
# Qt no longer has NaN values. 1 inefficiencies
# running Q 12300
# Qt no longer has NaN values. 0 inefficiencies
# running Q 12325
# Qt no longer has NaN values. 7 inefficiencies
# running Q 12350
# Qt no longer has NaN values. 3 inefficiencies
# running Q 12375
# Qt no longer has NaN values. 1 inefficiencies
# running Q 12400
# Qt no longer has NaN values. 4 inefficiencies
# running Q 12425
# Qt no longer has NaN values. 0 inefficiencies
# running Q 12450
# Qt no longer has NaN values. 0 inefficiencies
# running Q 12475
# Qt no longer has NaN values. 1 inefficiencies
# running Q 12500
# Qt no longer has NaN values. 1 inefficiencies
# running Q 12525
# Qt no longer has NaN values. 0 inefficiencies
# running Q 12550
# Qt no longer has NaN values. 0 inefficiencies
# running Q 12575
# Qt no longer has NaN values. 0 inefficiencies
# running Q 12600
# Qt no longer has NaN values. 2 inefficiencies
# running Q 12625
# Qt no longer has NaN values. 1 inefficiencies
# running Q 12650
# Qt no longer has NaN values. 0 inefficiencies
# running Q 12675
# Qt no longer has NaN values. 0 inefficiencies
# running Q 12700
# Qt no longer has NaN values. 0 inefficiencies
# running Q 12725
# Qt no longer has NaN values. 0 inefficiencies
# running Q 12750
# Qt no longer has NaN values. 0 inefficiencies
# running Q 12775
# Qt no longer has NaN values. 0 inefficiencies
# running Q 12800
# Qt no longer has NaN values. 0 inefficiencies
# running Q 12825
# Qt no longer has NaN values. 0 inefficiencies
# running Q 12850
# Qt no longer has NaN values. 0 inefficiencies
# running Q 12875
# Qt no longer has NaN values. 0 inefficiencies
# running Q 12900
# Qt no longer has NaN values. 0 inefficiencies
# running Q 12925
# Qt no longer has NaN values. 0 inefficiencies
# running Q 12950
# Qt no longer has NaN values. 0 inefficiencies
# running Q 12975
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13000
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13025
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13050
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13075
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13100
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13125
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13150
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13175
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13200
# Qt no longer has NaN values. 2 inefficiencies
# running Q 13225
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13250
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13275
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13300
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13325
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13350
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13375
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13400
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13425
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13450
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13475
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13500
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13525
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13550
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13575
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13600
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13625
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13650
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13675
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13700
# Qt no longer has NaN values. 1 inefficiencies
# running Q 13725
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13750
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13775
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13800
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13825
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13850
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13875
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13900
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13925
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13950
# Qt no longer has NaN values. 0 inefficiencies
# running Q 13975
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14000
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14025
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14050
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14075
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14100
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14125
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14150
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14175
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14200
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14225
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14250
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14275
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14300
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14325
# Qt no longer has NaN values. 2 inefficiencies
# running Q 14350
# Qt no longer has NaN values. 1 inefficiencies
# running Q 14375
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14400
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14425
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14450
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14475
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14500
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14525
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14550
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14575
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14600
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14625
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14650
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14675
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14700
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14725
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14750
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14775
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14800
# Qt no longer has NaN values. 1 inefficiencies
# running Q 14825
# Qt no longer has NaN values. 1 inefficiencies
# running Q 14850
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14875
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14900
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14925
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14950
# Qt no longer has NaN values. 0 inefficiencies
# running Q 14975
# Qt no longer has NaN values. 1 inefficiencies
# running Q 15000
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15025
# Qt no longer has NaN values. 1 inefficiencies
# running Q 15050
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15075
# Qt no longer has NaN values. 1 inefficiencies
# running Q 15100
# Qt no longer has NaN values. 1 inefficiencies
# running Q 15125
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15150
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15175
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15200
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15225
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15250
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15275
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15300
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15325
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15350
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15375
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15400
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15425
# Qt no longer has NaN values. 3 inefficiencies
# running Q 15450
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15475
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15500
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15525
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15550
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15575
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15600
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15625
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15650
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15675
# Qt no longer has NaN values. 3 inefficiencies
# running Q 15700
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15725
# Qt no longer has NaN values. 1 inefficiencies
# running Q 15750
# Qt no longer has NaN values. 1 inefficiencies
# running Q 15775
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15800
# Qt no longer has NaN values. 1 inefficiencies
# running Q 15825
# Qt no longer has NaN values. 1 inefficiencies
# running Q 15850
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15875
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15900
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15925
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15950
# Qt no longer has NaN values. 0 inefficiencies
# running Q 15975
# Qt no longer has NaN values. 1 inefficiencies
# running Q 16000
# Qt no longer has NaN values. 0 inefficiencies
# running Q 16025
# Qt no longer has NaN values. 0 inefficiencies
# running Q 16050
# Qt no longer has NaN values. 0 inefficiencies
# running Q 16075
# Qt no longer has NaN values. 0 inefficiencies
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\urllib3\connectionpool.py:403, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     402 try:
# --> 403     self._validate_conn(conn)
#     404 except (SocketTimeout, BaseSSLError) as e:
#     405     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1053, in HTTPSConnectionPool._validate_conn(self, conn)
#    1052 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1053     conn.connect()
#    1055 if not conn.is_verified:
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\urllib3\connection.py:419, in HTTPSConnection.connect(self)
#     417     context.load_default_certs()
# --> 419 self.sock = ssl_wrap_socket(
#     420     sock=conn,
#     421     keyfile=self.key_file,
#     422     certfile=self.cert_file,
#     423     key_password=self.key_password,
#     424     ca_certs=self.ca_certs,
#     425     ca_cert_dir=self.ca_cert_dir,
#     426     ca_cert_data=self.ca_cert_data,
#     427     server_hostname=server_hostname,
#     428     ssl_context=context,
#     429     tls_in_tls=tls_in_tls,
#     430 )
#     432 # If we're using all defaults and the connection
#     433 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     434 # for the host.
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\urllib3\util\ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\urllib3\util\ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#
# File c:\Users\Maxparizot\anaconda3\Lib\ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File c:\Users\Maxparizot\anaconda3\Lib\ssl.py:1108, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1107             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1108         self.do_handshake()
#    1109 except (OSError, ValueError):
#
# File c:\Users\Maxparizot\anaconda3\Lib\ssl.py:1379, in SSLSocket.do_handshake(self, block)
#    1378         self.settimeout(None)
# -> 1379     self._sslobj.do_handshake()
#    1380 finally:
#
# ConnectionAbortedError: [WinError 10053] An established connection was aborted by the software in your host machine
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\urllib3\connectionpool.py:798, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     796     e = ProtocolError("Connection aborted.", e)
# --> 798 retries = retries.increment(
#     799     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     800 )
#     801 retries.sleep()
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\urllib3\util\retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\urllib3\packages\six.py:769, in reraise(tp, value, tb)
#     768 if value.__traceback__ is not tb:
# --> 769     raise value.with_traceback(tb)
#     770 raise value
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\urllib3\connectionpool.py:403, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     402 try:
# --> 403     self._validate_conn(conn)
#     404 except (SocketTimeout, BaseSSLError) as e:
#     405     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1053, in HTTPSConnectionPool._validate_conn(self, conn)
#    1052 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1053     conn.connect()
#    1055 if not conn.is_verified:
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\urllib3\connection.py:419, in HTTPSConnection.connect(self)
#     417     context.load_default_certs()
# --> 419 self.sock = ssl_wrap_socket(
#     420     sock=conn,
#     421     keyfile=self.key_file,
#     422     certfile=self.cert_file,
#     423     key_password=self.key_password,
#     424     ca_certs=self.ca_certs,
#     425     ca_cert_dir=self.ca_cert_dir,
#     426     ca_cert_data=self.ca_cert_data,
#     427     server_hostname=server_hostname,
#     428     ssl_context=context,
#     429     tls_in_tls=tls_in_tls,
#     430 )
#     432 # If we're using all defaults and the connection
#     433 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     434 # for the host.
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\urllib3\util\ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\urllib3\util\ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#
# File c:\Users\Maxparizot\anaconda3\Lib\ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File c:\Users\Maxparizot\anaconda3\Lib\ssl.py:1108, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1107             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1108         self.do_handshake()
#    1109 except (OSError, ValueError):
#
# File c:\Users\Maxparizot\anaconda3\Lib\ssl.py:1379, in SSLSocket.do_handshake(self, block)
#    1378         self.settimeout(None)
# -> 1379     self._sslobj.do_handshake()
#    1380 finally:
#
# ProtocolError: ('Connection aborted.', ConnectionAbortedError(10053, 'An established connection was aborted by the software in your host machine', None, 10053, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[1], line 29
#      27 while True:
#      28     start_time = time.time()
# ---> 29     ask_prices, ask_volumes, ask_timestamps, bid_prices, bid_volumes, bid_timestamps, mid_price,ImbalanceRatio = Q.get_LOB(requests.get('https://api.kraken.com/0/public/Depth?pair=XBTUSD'))
#      30     #print('got data', counter)
#      31
#      32     # Create a new row
#      33     new_row = {'t': bid_timestamps[0], 'S': mid_price, 'I': ImbalanceRatio, 'MOBid':bid_prices[0], 'MOAsk': ask_prices[0]}
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\requests\adapters.py:501, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#    (...)
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
# --> 501     raise ConnectionError(err, request=request)
#     503 except MaxRetryError as e:
#     504     if isinstance(e.reason, ConnectTimeoutError):
#     505         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', ConnectionAbortedError(10053, 'An established connection was aborted by the software in your host machine', None, 10053, None))

# %%
#trade on Q code block

   #Data is the validation data
    #Q is the trading matrix
    #n is the number of bins
    #N is the number of ticks
    #cash is the amount of cash to start with
    #prob_limit is the probability limit for trading between 0 and 1


# Extract relevant data from the input structure 'Data'
from sympy import true
# Obtain states and corresponding indices using the getStates function
numBins = 5 # Number of bins for the imbalance ratio
dI = 20 # Number of ticks for the price change
# Initialize trading variables
start_counter=counter
counter = 0 # Counter for the trading loop
assets = 0   # Number of assets (stocks) held initially
cash=1000 # Starting cash
# Active trading loop
CASH = []
ASSETS = []
POSITIONS = []
    # Loop through each time point for active trading
while true:
    start_time = time.time()
    ask_prices, ask_volumes, ask_timestamps, bid_prices, bid_volumes, bid_timestamps, mid_price,ImbalanceRatio = Q.get_LOB(requests.get('https://api.kraken.com/0/public/Depth?pair=XBTUSD'))
    # Create a new row
    new_row = {'t': bid_timestamps[0], 'S': mid_price, 'I': ImbalanceRatio, 'MOBid':bid_prices[0], 'MOAsk': ask_prices[0]}
    # Append the new row to the DataFrame
    Data=pd.concat([Data, pd.DataFrame(new_row, index=[0])], ignore_index=True)
    [rho, DS] = get_states(Data, numBins, dI)

    # Increment the counter
    counter += 1
    # Get row and column indices for the current state in the Q matrix
    row = rho[tt-1] + n * (DS[tt-1] + 1) -1
    downColumn = rho[tt] -1
    upColumn = rho[tt] + 2 * n  -1

    # If predicting a downward price move
    if Q[row, downColumn] > .5+ prob_limit:
        if assets>=1:
            cash = cash + MOBid[tt] # Sell
            assets = assets - 1
        elif -(assets-1)*MOAsk[tt]<cash + (assets-1) *MOAsk[tt]:
            cash = cash + MOBid[tt]
            assets = assets - 1

    # If predicting an upward price move
    elif Q[row, upColumn] > .5+ prob_limit:
        if cash>MOAsk[tt]:
            cash = cash - MOAsk[tt] # Buy
            assets = assets + 1
    
    CASH[tt] = cash
    ASSETS[tt] = assets
    POSITIONS[tt]=cash+assets*MOBid[tt]


# End of trading: liquidate position
if assets > 0:
    cash = cash + assets * MOBid[T-1] # Sell off remaining assets
elif assets < 0:
    cash = cash + assets * MOAsk[T-1] # Buy back remaining short positions
    
CASH[T-N+1] = cash
ASSETS[T-N+1] = assets
POSITIONS[T-N+1]=cash+assets*MOBid[tt]
# Out:
# starting while loop
# running Q 25
# Qt_old (0,) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# <__array_function__ internals>:200: RuntimeWarning: invalid value encountered in cast
# c:\Users\Maxparizot\Documents\GitHub\TradeonQ\Code_3\dynamic_Q.py:84: RuntimeWarning: invalid value encountered in divide
#   G = C / H
# running Q 50
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 75
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# c:\Users\Maxparizot\Documents\GitHub\TradeonQ\Code_3\dynamic_Q.py:84: RuntimeWarning: divide by zero encountered in divide
#   G = C / H
# running Q 100
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 125
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 150
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 175
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 200
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 225
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 250
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 275
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 300
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 325
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 350
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 375
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 400
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 425
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 450
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 475
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 500
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 525
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 550
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 575
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 600
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 625
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 650
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 675
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 700
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 725
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 750
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 775
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 800
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 825
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 850
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 875
# Qt_old (15, 15) and Qt (15, 15) have NaN values. Qt_old is now Qt.
# running Q 900
# Qt no longer has NaN values. 0 inefficiencies
# running Q 925
# Qt no longer has NaN values. 10 inefficiencies
# running Q 950
# Qt no longer has NaN values. 9 inefficiencies
# running Q 975
# Qt no longer has NaN values. 5 inefficiencies
# running Q 1000
# Qt no longer has NaN values. 2 inefficiencies
# running Q 1025
# Qt no longer has NaN values. 4 inefficiencies
# running Q 1050
# Qt no longer has NaN values. 1 inefficiencies
# running Q 1075
# Qt no longer has NaN values. 4 inefficiencies
# running Q 1100
# Qt no longer has NaN values. 5 inefficiencies
# running Q 1125
# Qt no longer has NaN values. 12 inefficiencies
# running Q 1150
# Qt no longer has NaN values. 3 inefficiencies
# running Q 1175
# Qt no longer has NaN values. 0 inefficiencies
# running Q 1200
# Qt no longer has NaN values. 0 inefficiencies
# running Q 1225
# Qt no longer has NaN values. 0 inefficiencies
# running Q 1250
# Qt no longer has NaN values. 0 inefficiencies
# running Q 1275
# Qt no longer has NaN values. 2 inefficiencies
# running Q 1300
# Qt no longer has NaN values. 1 inefficiencies
# running Q 1325
# Qt no longer has NaN values. 0 inefficiencies
# running Q 1350
# Qt no longer has NaN values. 0 inefficiencies
# running Q 1375
# Qt no longer has NaN values. 0 inefficiencies
# running Q 1400
# Qt no longer has NaN values. 14 inefficiencies
# running Q 1425
# Qt no longer has NaN values. 1 inefficiencies
# running Q 1450
# Qt no longer has NaN values. 11 inefficiencies
# running Q 1475
# Qt no longer has NaN values. 0 inefficiencies
# running Q 1500
# Qt no longer has NaN values. 0 inefficiencies
# running Q 1525
# Qt no longer has NaN values. 0 inefficiencies
# running Q 1550
# Qt no longer has NaN values. 0 inefficiencies
# running Q 1575
# Qt no longer has NaN values. 0 inefficiencies
# running Q 1600
# Qt no longer has NaN values. 0 inefficiencies
# running Q 1625
# Qt no longer has NaN values. 0 inefficiencies
# running Q 1650
# Qt no longer has NaN values. 0 inefficiencies
# running Q 1675
# Qt no longer has NaN values. 0 inefficiencies
# running Q 1700
# Qt no longer has NaN values. 0 inefficiencies
# running Q 1725
# Qt no longer has NaN values. 0 inefficiencies
# running Q 1750
# Qt no longer has NaN values. 0 inefficiencies
# running Q 1775
# Qt no longer has NaN values. 0 inefficiencies
# running Q 1800
# Qt no longer has NaN values. 0 inefficiencies
# running Q 1825
# Qt no longer has NaN values. 0 inefficiencies
# running Q 1850
# Qt no longer has NaN values. 0 inefficiencies
# running Q 1875
# Qt no longer has NaN values. 0 inefficiencies
# running Q 1900
# Qt no longer has NaN values. 0 inefficiencies
# running Q 1925
# Qt no longer has NaN values. 0 inefficiencies
# running Q 1950
# Qt no longer has NaN values. 0 inefficiencies
# running Q 1975
# Qt no longer has NaN values. 2 inefficiencies
# running Q 2000
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2025
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2050
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2075
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2100
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2125
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2150
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2175
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2200
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2225
# Qt no longer has NaN values. 1 inefficiencies
# running Q 2250
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2275
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2300
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2325
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2350
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2375
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2400
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2425
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2450
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2475
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2500
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2525
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2550
# Qt no longer has NaN values. 1 inefficiencies
# running Q 2575
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2600
# Qt no longer has NaN values. 4 inefficiencies
# running Q 2625
# Qt no longer has NaN values. 3 inefficiencies
# running Q 2650
# Qt no longer has NaN values. 3 inefficiencies
# running Q 2675
# Qt no longer has NaN values. 4 inefficiencies
# running Q 2700
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2725
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2750
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2775
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2800
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2825
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2850
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2875
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2900
# Qt no longer has NaN values. 1 inefficiencies
# running Q 2925
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2950
# Qt no longer has NaN values. 0 inefficiencies
# running Q 2975
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3000
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3025
# Qt no longer has NaN values. 8 inefficiencies
# running Q 3050
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3075
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3100
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3125
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3150
# Qt no longer has NaN values. 3 inefficiencies
# running Q 3175
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3200
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3225
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3250
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3275
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3300
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3325
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3350
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3375
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3400
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3425
# Qt no longer has NaN values. 4 inefficiencies
# running Q 3450
# Qt no longer has NaN values. 1 inefficiencies
# running Q 3475
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3500
# Qt no longer has NaN values. 4 inefficiencies
# running Q 3525
# Qt no longer has NaN values. 1 inefficiencies
# running Q 3550
# Qt no longer has NaN values. 2 inefficiencies
# running Q 3575
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3600
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3625
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3650
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3675
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3700
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3725
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3750
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3775
# Qt no longer has NaN values. 1 inefficiencies
# running Q 3800
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3825
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3850
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3875
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3900
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3925
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3950
# Qt no longer has NaN values. 0 inefficiencies
# running Q 3975
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4000
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4025
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4050
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4075
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4100
# Qt no longer has NaN values. 4 inefficiencies
# running Q 4125
# Qt no longer has NaN values. 1 inefficiencies
# running Q 4150
# Qt no longer has NaN values. 3 inefficiencies
# running Q 4175
# Qt no longer has NaN values. 1 inefficiencies
# running Q 4200
# Qt no longer has NaN values. 5 inefficiencies
# running Q 4225
# Qt no longer has NaN values. 1 inefficiencies
# running Q 4250
# Qt no longer has NaN values. 2 inefficiencies
# running Q 4275
# Qt no longer has NaN values. 1 inefficiencies
# running Q 4300
# Qt no longer has NaN values. 2 inefficiencies
# running Q 4325
# Qt no longer has NaN values. 1 inefficiencies
# running Q 4350
# Qt no longer has NaN values. 1 inefficiencies
# running Q 4375
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4400
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4425
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4450
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4475
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4500
# Qt no longer has NaN values. 1 inefficiencies
# running Q 4525
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4550
# Qt no longer has NaN values. 2 inefficiencies
# running Q 4575
# Qt no longer has NaN values. 1 inefficiencies
# running Q 4600
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4625
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4650
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4675
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4700
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4725
# Qt no longer has NaN values. 1 inefficiencies
# running Q 4750
# Qt no longer has NaN values. 2 inefficiencies
# running Q 4775
# Qt no longer has NaN values. 4 inefficiencies
# running Q 4800
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4825
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4850
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4875
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4900
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4925
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4950
# Qt no longer has NaN values. 0 inefficiencies
# running Q 4975
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5000
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5025
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5050
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5075
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5100
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5125
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5150
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5175
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5200
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5225
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5250
# Qt no longer has NaN values. 1 inefficiencies
# running Q 5275
# Qt no longer has NaN values. 1 inefficiencies
# running Q 5300
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5325
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5350
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5375
# Qt no longer has NaN values. 4 inefficiencies
# running Q 5400
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5425
# Qt no longer has NaN values. 11 inefficiencies
# running Q 5450
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5475
# Qt no longer has NaN values. 4 inefficiencies
# running Q 5500
# Qt no longer has NaN values. 1 inefficiencies
# running Q 5525
# Qt no longer has NaN values. 3 inefficiencies
# running Q 5550
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5575
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5600
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5625
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5650
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5675
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5700
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5725
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5750
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5775
# Qt no longer has NaN values. 2 inefficiencies
# running Q 5800
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5825
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5850
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5875
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5900
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5925
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5950
# Qt no longer has NaN values. 0 inefficiencies
# running Q 5975
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6000
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6025
# Qt no longer has NaN values. 1 inefficiencies
# running Q 6050
# Qt no longer has NaN values. 1 inefficiencies
# running Q 6075
# Qt no longer has NaN values. 1 inefficiencies
# running Q 6100
# Qt no longer has NaN values. 2 inefficiencies
# running Q 6125
# Qt no longer has NaN values. 2 inefficiencies
# running Q 6150
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6175
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6200
# Qt no longer has NaN values. 2 inefficiencies
# running Q 6225
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6250
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6275
# Qt no longer has NaN values. 1 inefficiencies
# running Q 6300
# Qt no longer has NaN values. 1 inefficiencies
# running Q 6325
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6350
# Qt no longer has NaN values. 1 inefficiencies
# running Q 6375
# Qt no longer has NaN values. 3 inefficiencies
# running Q 6400
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6425
# Qt no longer has NaN values. 1 inefficiencies
# running Q 6450
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6475
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6500
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6525
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6550
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6575
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6600
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6625
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6650
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6675
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6700
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6725
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6750
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6775
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6800
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6825
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6850
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6875
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6900
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6925
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6950
# Qt no longer has NaN values. 0 inefficiencies
# running Q 6975
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7000
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7025
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7050
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7075
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7100
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7125
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7150
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7175
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7200
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7225
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7250
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7275
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7300
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7325
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7350
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7375
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7400
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7425
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7450
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7475
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7500
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7525
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7550
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7575
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7600
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7625
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7650
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7675
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7700
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7725
# Qt no longer has NaN values. 1 inefficiencies
# running Q 7750
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7775
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7800
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7825
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7850
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7875
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7900
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7925
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7950
# Qt no longer has NaN values. 0 inefficiencies
# running Q 7975
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8000
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8025
# Qt no longer has NaN values. 1 inefficiencies
# running Q 8050
# Qt no longer has NaN values. 1 inefficiencies
# running Q 8075
# Qt no longer has NaN values. 1 inefficiencies
# running Q 8100
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8125
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8150
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8175
# Qt no longer has NaN values. 1 inefficiencies
# running Q 8200
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8225
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8250
# Qt no longer has NaN values. 0 inefficiencies
# running Q 8275
# Qt no longer has NaN values. 0 inefficiencies
# Q has converged in 8275 values.

# %%
# this code is to generate backtest data for the Q function
import dynamic_Q as Q
import requests
import numpy as np
from scipy.linalg import expm
from skopt import BayesSearchCV
from skopt.space import Integer
from datetime import datetime, timedelta
import pandas as pd

def lobster_data(data1, data2):
    # Extract time from the first column of data1
    Time = data1[:, 1]

   # Assuming data2 is a NumPy array
    num_rows, num_cols = data2.shape
    num_levels = num_cols // 4

    # Reshape data2 to match the desired structure
    data_reshaped = data2.reshape((num_rows, num_levels, 4))

    # Extract MOBid, bid_volume, MOAsk, and ask_volume from reshaped data
    MOAsk = data_reshaped[:, :, 0]  # Ask Price
    ask_volume = data_reshaped[:, :, 1]  # Ask Size 
    MOBid = data_reshaped[:, :, 2]  # Bid Price
    bid_volume = data_reshaped[:, :, 3]  # Bid Size

    return MOBid, bid_volume, MOAsk, ask_volume, Time
# Replace 'your_file.csv' with the actual path to your CSV file
file_path1 = 'C:\\Users\\Maxparizot\\Documents\\GitHub\\TradeonQ\\LOB3Example - Matlab example\\LOBSupportingFiles\\MSFT_2012-06-21_34200000_57600000_message_10.csv'
file_path2 = 'C:\\Users\\Maxparizot\\Documents\\GitHub\\TradeonQ\\LOB3Example - Matlab example\\LOBSupportingFiles\\MSFT_2012-06-21_34200000_57600000_orderbook_10.csv'

# Read the CSV file into a DataFrame
data1 = np.loadtxt(file_path1,delimiter=',')
data2= np.loadtxt(file_path2,delimiter=',')

MOBid, bid_volume, MOAsk, ask_volume, Time = lobster_data(data1, data2)

# Calculate midprice for each entry in MoBid and MoAsk
S = np.array([Q.midprice(MOBid[price, 0], MOAsk[price, 0]) for price in range(MOBid.shape[0])])

# find Imbalance index
I = np.array([Q.imbalance_ratio(bid_volume[time, :], ask_volume[time, :]) for time in range(bid_volume.shape[0])])


# Set your reference time (midnight)
reference_time = datetime(2012, 6, 21, 0, 0, 0)
t = [reference_time + timedelta(seconds=duration) for duration in Time]

# Creating a DataFrame in Python using Pandas
Data = pd.DataFrame({'t': t, 'S': S, 'I': I, 'MOBid': MOBid[:,0], 'MOAsk': MOAsk[:,0]})
# 't' is the timestamp, set it as the index

#separate data into training and validating data
bp = round(0.80 * len(t))  # Use 80% of data for training
TData = Data.iloc[:bp, :]  # Training data
VData = Data.iloc[bp:, :]  # Validation data

# %%
import pandas as pd

# Convert your list to a DataFrame
df = pd.DataFrame(inhomogeneity_convergence, columns=['Inhomogeneity'])

# Write the DataFrame to an Excel file
df.to_excel('Inhomogeneity_convergence.xlsx', index=False)

# %%
import multiprocessing as mp

#this code block is to dynamically build Q until convergence
#it can be put into a function and all values of interest can be returned. However! You want to store everything to see the result at it progresses.
import dynamic_Q as Q
import requests
import numpy as np
from scipy.linalg import expm
from skopt import BayesSearchCV
from skopt.space import Integer
from datetime import datetime, timedelta
import pandas as pd
import numpy as np
from scipy.signal import convolve
import time

def calculate_Q(queue, Data, n, N):
    Qt= Q.make_Q(Data, n, N)
    queue.put(Qt)
    return

# Create a Queue object
queue = mp.SimpleQueue()
process = None

# Initialize Variables
Data = pd.DataFrame({'t': [], 'S': [], 'I': [], 'MOBid':[], 'MOAsk': []})
inhomogeneity_convergence = []
Qt_old = np.array([])
Qt = np.array([np.nan])

#initialize parameters
n=5
N=20
counter = 0
tolerance = 0.1 #Convergence Tolerance

print('starting while loop')
while True:
    start_time = time.time()
    ask_prices, ask_volumes, ask_timestamps, bid_prices, bid_volumes, bid_timestamps, mid_price,ImbalanceRatio = Q.get_LOB(requests.get('https://api.kraken.com/0/public/Depth?pair=XBTUSD'))
    #print('got data', counter)
    
    # Create a new row
    new_row = {'t': bid_timestamps[0], 'S': mid_price, 'I': ImbalanceRatio, 'MOBid':bid_prices[0], 'MOAsk': ask_prices[0]}
    # Append the new row to the DataFrame
    Data=pd.concat([Data, pd.DataFrame(new_row, index=[0])], ignore_index=True)

    # Increment the counter
    counter += 1

    # Every 25 iterations (every 5 seconds), run the Q function
    if counter > 25:
        # If a previous process finished running, get its result
        if process and process.is_alive() == False:
            print('getting Q from previous process', counter)
            try:
                Qt = queue.get(block=False)
            except Exception:
                print("Queue is empty")
            process = None

        # Start a new process to calculate Qt if there is no process running
        if process is None:
            print('running Q on separate process', counter)
            process = mp.Process(target=calculate_Q, args=(queue, Data, n, N))
            process.start()
            
        if not np.isnan(Qt).any():
            print("Qt no longer has NaN values.")
            Q_diff=Qt_old - Qt
            Inhomogeneity= sum ((Qt_old > 0.5) & (Qt < 0.5) | (Qt_old < 0.5) & (Qt > 0.5)) #trading inefficiencies, which result from indices (market states) where one matrix gives a trading cue (probability value > 0.5) and the other does not.
            inhomogeneity_convergence.append(Inhomogeneity) #store data for future plotting

            if max(Q_diff) < tolerance:
                print("Q has converged in {} values.".format(counter))
                break
            Qt_old = Qt
    
    end_time = time.time()
    if end_time - start_time <.33 :
        time.sleep(.33 - (end_time - start_time))
    


print("Number of cpu : ", mp.multiprocessing.cpu_count())
# Out:
# starting while loop
# running Q on separate process 26
# getting Q from previous process 27
# Queue is empty
# running Q on separate process 27
# getting Q from previous process 28
# Queue is empty
# running Q on separate process 28
# getting Q from previous process 29
# Queue is empty
# running Q on separate process 29
# getting Q from previous process 30
# Queue is empty
# running Q on separate process 30
# getting Q from previous process 31
# Queue is empty
# running Q on separate process 31
# getting Q from previous process 32
# Queue is empty
# running Q on separate process 32
# getting Q from previous process 33
# Queue is empty
# running Q on separate process 33
# getting Q from previous process 34
# Queue is empty
# running Q on separate process 34
# getting Q from previous process 35
# Queue is empty
# running Q on separate process 35
# getting Q from previous process 36
# Queue is empty
# running Q on separate process 36
# getting Q from previous process 37
# Queue is empty
# running Q on separate process 37
# getting Q from previous process 38
# Queue is empty
# running Q on separate process 38
# getting Q from previous process 39
# Queue is empty
# running Q on separate process 39
# getting Q from previous process 40
# Queue is empty
# running Q on separate process 40
# getting Q from previous process 41
# Queue is empty
# running Q on separate process 41
# getting Q from previous process 42
# Queue is empty
# running Q on separate process 42
# getting Q from previous process 43
# Queue is empty
# running Q on separate process 43
# getting Q from previous process 44
# Queue is empty
# running Q on separate process 44
# getting Q from previous process 45
# Queue is empty
# running Q on separate process 45
# getting Q from previous process 46
# Queue is empty
# running Q on separate process 46
# getting Q from previous process 47
# Queue is empty
# running Q on separate process 47
# getting Q from previous process 48
# Queue is empty
# running Q on separate process 48
# getting Q from previous process 49
# Queue is empty
# running Q on separate process 49
# getting Q from previous process 50
# Queue is empty
# running Q on separate process 50
# getting Q from previous process 51
# Queue is empty
# running Q on separate process 51
# getting Q from previous process 52
# Queue is empty
# running Q on separate process 52
# getting Q from previous process 53
# Queue is empty
# running Q on separate process 53
# getting Q from previous process 54
# Queue is empty
# running Q on separate process 54
# getting Q from previous process 55
# Queue is empty
# running Q on separate process 55
# getting Q from previous process 56
# Queue is empty
# running Q on separate process 56
# getting Q from previous process 57
# Queue is empty
# running Q on separate process 57
# getting Q from previous process 58
# Queue is empty
# running Q on separate process 58
# getting Q from previous process 59
# Queue is empty
# running Q on separate process 59
# getting Q from previous process 60
# Queue is empty
# running Q on separate process 60
# getting Q from previous process 61
# Queue is empty
# running Q on separate process 61
# getting Q from previous process 62
# Queue is empty
# running Q on separate process 62
# getting Q from previous process 63
# Queue is empty
# running Q on separate process 63
# getting Q from previous process 64
# Queue is empty
# running Q on separate process 64
# getting Q from previous process 65
# Queue is empty
# running Q on separate process 65
# getting Q from previous process 66
# Queue is empty
# running Q on separate process 66
# getting Q from previous process 67
# Queue is empty
# running Q on separate process 67
# getting Q from previous process 68
# Queue is empty
# running Q on separate process 68
# getting Q from previous process 69
# Queue is empty
# running Q on separate process 69
# getting Q from previous process 70
# Queue is empty
# running Q on separate process 70
# getting Q from previous process 71
# Queue is empty
# running Q on separate process 71
# getting Q from previous process 72
# Queue is empty
# running Q on separate process 72
# getting Q from previous process 73
# Queue is empty
# running Q on separate process 73
# getting Q from previous process 74
# Queue is empty
# running Q on separate process 74
# getting Q from previous process 75
# Queue is empty
# running Q on separate process 75
# getting Q from previous process 76
# Queue is empty
# running Q on separate process 76
# getting Q from previous process 77
# Queue is empty
# running Q on separate process 77
# getting Q from previous process 78
# Queue is empty
# running Q on separate process 78
# getting Q from previous process 79
# Queue is empty
# running Q on separate process 79
# getting Q from previous process 80
# Queue is empty
# running Q on separate process 80
# getting Q from previous process 81
# Queue is empty
# running Q on separate process 81
# getting Q from previous process 82
# Queue is empty
# running Q on separate process 82
# getting Q from previous process 83
# Queue is empty
# running Q on separate process 83
# getting Q from previous process 84
# Queue is empty
# running Q on separate process 84
# getting Q from previous process 85
# Queue is empty
# running Q on separate process 85
# getting Q from previous process 86
# Queue is empty
# running Q on separate process 86
# getting Q from previous process 87
# Queue is empty
# running Q on separate process 87
# getting Q from previous process 88
# Queue is empty
# running Q on separate process 88
# getting Q from previous process 89
# Queue is empty
# running Q on separate process 89
# getting Q from previous process 90
# Queue is empty
# running Q on separate process 90
# getting Q from previous process 91
# Queue is empty
# running Q on separate process 91
# getting Q from previous process 92
# Queue is empty
# running Q on separate process 92
# getting Q from previous process 93
# Queue is empty
# running Q on separate process 93
# getting Q from previous process 94
# Queue is empty
# running Q on separate process 94
# getting Q from previous process 95
# Queue is empty
# running Q on separate process 95
# getting Q from previous process 96
# Queue is empty
# running Q on separate process 96
# getting Q from previous process 97
# Queue is empty
# running Q on separate process 97
# getting Q from previous process 98
# Queue is empty
# running Q on separate process 98
# getting Q from previous process 99
# Queue is empty
# running Q on separate process 99
# getting Q from previous process 100
# Queue is empty
# running Q on separate process 100
# getting Q from previous process 101
# Queue is empty
# running Q on separate process 101
# getting Q from previous process 102
# Queue is empty
# running Q on separate process 102
# getting Q from previous process 103
# Queue is empty
# running Q on separate process 103
# getting Q from previous process 104
# Queue is empty
# running Q on separate process 104
# getting Q from previous process 105
# Queue is empty
# running Q on separate process 105
# getting Q from previous process 106
# Queue is empty
# running Q on separate process 106
# getting Q from previous process 107
# Queue is empty
# running Q on separate process 107
# getting Q from previous process 108
# Queue is empty
# running Q on separate process 108
# getting Q from previous process 109
# Queue is empty
# running Q on separate process 109
# getting Q from previous process 110
# Queue is empty
# running Q on separate process 110
# getting Q from previous process 111
# Queue is empty
# running Q on separate process 111
# getting Q from previous process 112
# Queue is empty
# running Q on separate process 112
# getting Q from previous process 113
# Queue is empty
# running Q on separate process 113
# getting Q from previous process 114
# Queue is empty
# running Q on separate process 114
# getting Q from previous process 115
# Queue is empty
# running Q on separate process 115
# getting Q from previous process 116
# Queue is empty
# running Q on separate process 116
# getting Q from previous process 117
# Queue is empty
# running Q on separate process 117
# getting Q from previous process 118
# Queue is empty
# running Q on separate process 118
# getting Q from previous process 119
# Queue is empty
# running Q on separate process 119
# getting Q from previous process 120
# Queue is empty
# running Q on separate process 120
# getting Q from previous process 121
# Queue is empty
# running Q on separate process 121
# getting Q from previous process 122
# Queue is empty
# running Q on separate process 122
# getting Q from previous process 123
# Queue is empty
# running Q on separate process 123
# getting Q from previous process 124
# Queue is empty
# running Q on separate process 124
# getting Q from previous process 125
# Queue is empty
# running Q on separate process 125
# getting Q from previous process 126
# Queue is empty
# running Q on separate process 126
# getting Q from previous process 127
# Queue is empty
# running Q on separate process 127
# getting Q from previous process 128
# Queue is empty
# running Q on separate process 128
# getting Q from previous process 129
# Queue is empty
# running Q on separate process 129
# getting Q from previous process 130
# Queue is empty
# running Q on separate process 130
# getting Q from previous process 131
# Queue is empty
# running Q on separate process 131
# getting Q from previous process 132
# Queue is empty
# running Q on separate process 132
# getting Q from previous process 133
# Queue is empty
# running Q on separate process 133
# getting Q from previous process 134
# Queue is empty
# running Q on separate process 134
# getting Q from previous process 135
# Queue is empty
# running Q on separate process 135
# getting Q from previous process 136
# Queue is empty
# running Q on separate process 136
# getting Q from previous process 137
# Queue is empty
# running Q on separate process 137
# getting Q from previous process 138
# Queue is empty
# running Q on separate process 138
# getting Q from previous process 139
# Queue is empty
# running Q on separate process 139
# getting Q from previous process 140
# Queue is empty
# running Q on separate process 140
# getting Q from previous process 141
# Queue is empty
# running Q on separate process 141
# getting Q from previous process 142
# Queue is empty
# running Q on separate process 142
# getting Q from previous process 143
# Queue is empty
# running Q on separate process 143
# getting Q from previous process 144
# Queue is empty
# running Q on separate process 144
# getting Q from previous process 145
# Queue is empty
# running Q on separate process 145
# getting Q from previous process 146
# Queue is empty
# running Q on separate process 146
# getting Q from previous process 147
# Queue is empty
# running Q on separate process 147
# getting Q from previous process 148
# Queue is empty
# running Q on separate process 148
# getting Q from previous process 149
# Queue is empty
# running Q on separate process 149
# getting Q from previous process 150
# Queue is empty
# running Q on separate process 150
# getting Q from previous process 151
# Queue is empty
# running Q on separate process 151
# getting Q from previous process 152
# Queue is empty
# running Q on separate process 152
# getting Q from previous process 153
# Queue is empty
# running Q on separate process 153
# getting Q from previous process 154
# Queue is empty
# running Q on separate process 154
# getting Q from previous process 155
# Queue is empty
# running Q on separate process 155
# getting Q from previous process 156
# Queue is empty
# running Q on separate process 156
# getting Q from previous process 157
# Queue is empty
# running Q on separate process 157
# getting Q from previous process 158
# Queue is empty
# running Q on separate process 158
# getting Q from previous process 159
# Queue is empty
# running Q on separate process 159
# getting Q from previous process 160
# Queue is empty
# running Q on separate process 160
# getting Q from previous process 161
# Queue is empty
# running Q on separate process 161
# getting Q from previous process 162
# Queue is empty
# running Q on separate process 162
# getting Q from previous process 163
# Queue is empty
# running Q on separate process 163
# getting Q from previous process 164
# Queue is empty
# running Q on separate process 164
# getting Q from previous process 165
# Queue is empty
# running Q on separate process 165
# getting Q from previous process 166
# Queue is empty
# running Q on separate process 166
# getting Q from previous process 167
# Queue is empty
# running Q on separate process 167
# getting Q from previous process 168
# Queue is empty
# running Q on separate process 168
# getting Q from previous process 169
# Queue is empty
# running Q on separate process 169
# getting Q from previous process 170
# Queue is empty
# running Q on separate process 170
# getting Q from previous process 171
# Queue is empty
# running Q on separate process 171
# getting Q from previous process 172
# Queue is empty
# running Q on separate process 172
# getting Q from previous process 173
# Queue is empty
# running Q on separate process 173
# getting Q from previous process 174
# Queue is empty
# running Q on separate process 174
# getting Q from previous process 175
# Queue is empty
# running Q on separate process 175
# getting Q from previous process 176
# Queue is empty
# running Q on separate process 176
# getting Q from previous process 177
# Queue is empty
# running Q on separate process 177
# getting Q from previous process 178
# Queue is empty
# running Q on separate process 178
# getting Q from previous process 179
# Queue is empty
# running Q on separate process 179
# getting Q from previous process 180
# Queue is empty
# running Q on separate process 180
# getting Q from previous process 181
# Queue is empty
# running Q on separate process 181
# getting Q from previous process 182
# Queue is empty
# running Q on separate process 182
# getting Q from previous process 183
# Queue is empty
# running Q on separate process 183
# getting Q from previous process 184
# Queue is empty
# running Q on separate process 184
# getting Q from previous process 185
# Queue is empty
# running Q on separate process 185
# getting Q from previous process 186
# Queue is empty
# running Q on separate process 186
# getting Q from previous process 187
# Queue is empty
# running Q on separate process 187
# getting Q from previous process 188
# Queue is empty
# running Q on separate process 188
# getting Q from previous process 189
# Queue is empty
# running Q on separate process 189
# getting Q from previous process 190
# Queue is empty
# running Q on separate process 190
# getting Q from previous process 191
# Queue is empty
# running Q on separate process 191
# getting Q from previous process 192
# Queue is empty
# running Q on separate process 192
# getting Q from previous process 193
# Queue is empty
# running Q on separate process 193
# getting Q from previous process 194
# Queue is empty
# running Q on separate process 194
# getting Q from previous process 195
# Queue is empty
# running Q on separate process 195
# getting Q from previous process 196
# Queue is empty
# running Q on separate process 196
# getting Q from previous process 197
# Queue is empty
# running Q on separate process 197
# getting Q from previous process 198
# Queue is empty
# running Q on separate process 198
# getting Q from previous process 199
# Queue is empty
# running Q on separate process 199
# getting Q from previous process 200
# Queue is empty
# running Q on separate process 200
# getting Q from previous process 201
# Queue is empty
# running Q on separate process 201
# getting Q from previous process 202
# Queue is empty
# running Q on separate process 202
# getting Q from previous process 203
# Queue is empty
# running Q on separate process 203
# getting Q from previous process 204
# Queue is empty
# running Q on separate process 204
# getting Q from previous process 205
# Queue is empty
# running Q on separate process 205
# getting Q from previous process 206
# Queue is empty
# running Q on separate process 206
# getting Q from previous process 207
# Queue is empty
# running Q on separate process 207
# getting Q from previous process 208
# Queue is empty
# running Q on separate process 208
# getting Q from previous process 209
# Queue is empty
# running Q on separate process 209
# getting Q from previous process 210
# Queue is empty
# running Q on separate process 210
# getting Q from previous process 211
# Queue is empty
# running Q on separate process 211
# getting Q from previous process 212
# Queue is empty
# running Q on separate process 212
# getting Q from previous process 213
# Queue is empty
# running Q on separate process 213
# getting Q from previous process 214
# Queue is empty
# running Q on separate process 214
# getting Q from previous process 215
# Queue is empty
# running Q on separate process 215
# getting Q from previous process 216
# Queue is empty
# running Q on separate process 216
# getting Q from previous process 217
# Queue is empty
# running Q on separate process 217
# getting Q from previous process 218
# Queue is empty
# running Q on separate process 218
# getting Q from previous process 219
# Queue is empty
# running Q on separate process 219
# getting Q from previous process 220
# Queue is empty
# running Q on separate process 220
# getting Q from previous process 221
# Queue is empty
# running Q on separate process 221
# getting Q from previous process 222
# Queue is empty
# running Q on separate process 222
# getting Q from previous process 223
# Queue is empty
# running Q on separate process 223
# getting Q from previous process 224
# Queue is empty
# running Q on separate process 224
# getting Q from previous process 225
# Queue is empty
# running Q on separate process 225
# getting Q from previous process 226
# Queue is empty
# running Q on separate process 226
# getting Q from previous process 227
# Queue is empty
# running Q on separate process 227
# getting Q from previous process 228
# Queue is empty
# running Q on separate process 228
# getting Q from previous process 229
# Queue is empty
# running Q on separate process 229
# getting Q from previous process 230
# Queue is empty
# running Q on separate process 230
# getting Q from previous process 231
# Queue is empty
# running Q on separate process 231
# getting Q from previous process 232
# Queue is empty
# running Q on separate process 232
# getting Q from previous process 233
# Queue is empty
# running Q on separate process 233
# getting Q from previous process 234
# Queue is empty
# running Q on separate process 234
# getting Q from previous process 235
# Queue is empty
# running Q on separate process 235
# getting Q from previous process 236
# Queue is empty
# running Q on separate process 236
# getting Q from previous process 237
# Queue is empty
# running Q on separate process 237
# getting Q from previous process 238
# Queue is empty
# running Q on separate process 238
# getting Q from previous process 239
# Queue is empty
# running Q on separate process 239
# getting Q from previous process 240
# Queue is empty
# running Q on separate process 240
# getting Q from previous process 241
# Queue is empty
# running Q on separate process 241
# getting Q from previous process 242
# Queue is empty
# running Q on separate process 242
# getting Q from previous process 243
# Queue is empty
# running Q on separate process 243
# getting Q from previous process 244
# Queue is empty
# running Q on separate process 244
# getting Q from previous process 245
# Queue is empty
# running Q on separate process 245
# getting Q from previous process 246
# Queue is empty
# running Q on separate process 246
# getting Q from previous process 247
# Queue is empty
# running Q on separate process 247
# getting Q from previous process 248
# Queue is empty
# running Q on separate process 248
# getting Q from previous process 249
# Queue is empty
# running Q on separate process 249
# getting Q from previous process 250
# Queue is empty
# running Q on separate process 250
# getting Q from previous process 251
# Queue is empty
# running Q on separate process 251
# getting Q from previous process 252
# Queue is empty
# running Q on separate process 252
# getting Q from previous process 253
# Queue is empty
# running Q on separate process 253
# getting Q from previous process 254
# Queue is empty
# running Q on separate process 254
# getting Q from previous process 255
# Queue is empty
# running Q on separate process 255
# getting Q from previous process 256
# Queue is empty
# running Q on separate process 256
# getting Q from previous process 257
# Queue is empty
# running Q on separate process 257
# getting Q from previous process 258
# Queue is empty
# running Q on separate process 258
# getting Q from previous process 259
# Queue is empty
# running Q on separate process 259
# getting Q from previous process 260
# Queue is empty
# running Q on separate process 260
# getting Q from previous process 261
# Queue is empty
# running Q on separate process 261
# getting Q from previous process 262
# Queue is empty
# running Q on separate process 262
# getting Q from previous process 263
# Queue is empty
# running Q on separate process 263
# getting Q from previous process 264
# Queue is empty
# running Q on separate process 264
# getting Q from previous process 265
# Queue is empty
# running Q on separate process 265
# getting Q from previous process 266
# Queue is empty
# running Q on separate process 266
# getting Q from previous process 267
# Queue is empty
# running Q on separate process 267
# getting Q from previous process 268
# Queue is empty
# running Q on separate process 268
# getting Q from previous process 269
# Queue is empty
# running Q on separate process 269
# getting Q from previous process 270
# Queue is empty
# running Q on separate process 270
# getting Q from previous process 271
# Queue is empty
# running Q on separate process 271
# getting Q from previous process 272
# Queue is empty
# running Q on separate process 272
# getting Q from previous process 273
# Queue is empty
# running Q on separate process 273
# getting Q from previous process 274
# Queue is empty
# running Q on separate process 274
# getting Q from previous process 275
# Queue is empty
# running Q on separate process 275
# getting Q from previous process 276
# Queue is empty
# running Q on separate process 276
# getting Q from previous process 277
# Queue is empty
# running Q on separate process 277
# getting Q from previous process 278
# Queue is empty
# running Q on separate process 278
# getting Q from previous process 279
# Queue is empty
# running Q on separate process 279
# getting Q from previous process 280
# Queue is empty
# running Q on separate process 280
# getting Q from previous process 281
# Queue is empty
# running Q on separate process 281
# getting Q from previous process 282
# Queue is empty
# running Q on separate process 282
# getting Q from previous process 283
# Queue is empty
# running Q on separate process 283
# getting Q from previous process 284
# Queue is empty
# running Q on separate process 284
# getting Q from previous process 285
# Queue is empty
# running Q on separate process 285
# getting Q from previous process 286
# Queue is empty
# running Q on separate process 286
# getting Q from previous process 287
# Queue is empty
# running Q on separate process 287
# getting Q from previous process 288
# Queue is empty
# running Q on separate process 288
# getting Q from previous process 289
# Queue is empty
# running Q on separate process 289
# getting Q from previous process 290
# Queue is empty
# running Q on separate process 290
# getting Q from previous process 291
# Queue is empty
# running Q on separate process 291
# getting Q from previous process 292
# Queue is empty
# running Q on separate process 292
# getting Q from previous process 293
# Queue is empty
# running Q on separate process 293
# getting Q from previous process 294
# Queue is empty
# running Q on separate process 294
# getting Q from previous process 295
# Queue is empty
# running Q on separate process 295
# getting Q from previous process 296
# Queue is empty
# running Q on separate process 296
# getting Q from previous process 297
# Queue is empty
# running Q on separate process 297
# getting Q from previous process 298
# Queue is empty
# running Q on separate process 298
# getting Q from previous process 299
# Queue is empty
# running Q on separate process 299
# getting Q from previous process 300
# Queue is empty
# running Q on separate process 300
# getting Q from previous process 301
# Queue is empty
# running Q on separate process 301
# getting Q from previous process 302
# Queue is empty
# running Q on separate process 302
# getting Q from previous process 303
# Queue is empty
# running Q on separate process 303
# getting Q from previous process 304
# Queue is empty
# running Q on separate process 304
# getting Q from previous process 305
# Queue is empty
# running Q on separate process 305
# getting Q from previous process 306
# Queue is empty
# running Q on separate process 306
# getting Q from previous process 307
# Queue is empty
# running Q on separate process 307
# getting Q from previous process 308
# Queue is empty
# running Q on separate process 308
# getting Q from previous process 309
# Queue is empty
# running Q on separate process 309
# getting Q from previous process 310
# Queue is empty
# running Q on separate process 310
# getting Q from previous process 311
# Queue is empty
# running Q on separate process 311
# getting Q from previous process 312
# Queue is empty
# running Q on separate process 312
# getting Q from previous process 313
# Queue is empty
# running Q on separate process 313
# getting Q from previous process 314
# Queue is empty
# running Q on separate process 314
# getting Q from previous process 315
# Queue is empty
# running Q on separate process 315
# getting Q from previous process 316
# Queue is empty
# running Q on separate process 316
# getting Q from previous process 317
# Queue is empty
# running Q on separate process 317
# getting Q from previous process 318
# Queue is empty
# running Q on separate process 318
# getting Q from previous process 319
# Queue is empty
# running Q on separate process 319
# getting Q from previous process 320
# Queue is empty
# running Q on separate process 320
# getting Q from previous process 321
# Queue is empty
# running Q on separate process 321
# getting Q from previous process 322
# Queue is empty
# running Q on separate process 322
# getting Q from previous process 323
# Queue is empty
# running Q on separate process 323
# getting Q from previous process 324
# Queue is empty
# running Q on separate process 324
# getting Q from previous process 325
# Queue is empty
# running Q on separate process 325
# getting Q from previous process 326
# Queue is empty
# running Q on separate process 326
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 41
#      39 while True:
#      40     start_time = time.time()
# ---> 41     ask_prices, ask_volumes, ask_timestamps, bid_prices, bid_volumes, bid_timestamps, mid_price,ImbalanceRatio = Q.get_LOB(requests.get('https://api.kraken.com/0/public/Depth?pair=XBTUSD'))
#      42     #print('got data', counter)
#      43
#      44     # Create a new row
#      45     new_row = {'t': bid_timestamps[0], 'S': mid_price, 'I': ImbalanceRatio, 'MOBid':bid_prices[0], 'MOAsk': ask_prices[0]}
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\urllib3\connectionpool.py:403, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     401 # Trigger any extra validation we need to do.
#     402 try:
# --> 403     self._validate_conn(conn)
#     404 except (SocketTimeout, BaseSSLError) as e:
#     405     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     406     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1053, in HTTPSConnectionPool._validate_conn(self, conn)
#    1051 # Force connect early to allow us to validate the connection.
#    1052 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1053     conn.connect()
#    1055 if not conn.is_verified:
#    1056     warnings.warn(
#    1057         (
#    1058             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1063         InsecureRequestWarning,
#    1064     )
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\urllib3\connection.py:419, in HTTPSConnection.connect(self)
#     410 if (
#     411     not self.ca_certs
#     412     and not self.ca_cert_dir
#    (...)
#     415     and hasattr(context, "load_default_certs")
#     416 ):
#     417     context.load_default_certs()
# --> 419 self.sock = ssl_wrap_socket(
#     420     sock=conn,
#     421     keyfile=self.key_file,
#     422     certfile=self.cert_file,
#     423     key_password=self.key_password,
#     424     ca_certs=self.ca_certs,
#     425     ca_cert_dir=self.ca_cert_dir,
#     426     ca_cert_data=self.ca_cert_data,
#     427     server_hostname=server_hostname,
#     428     ssl_context=context,
#     429     tls_in_tls=tls_in_tls,
#     430 )
#     432 # If we're using all defaults and the connection
#     433 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     434 # for the host.
#     435 if (
#     436     default_ssl_context
#     437     and self.ssl_version is None
#     438     and hasattr(self.sock, "version")
#     439     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     440 ):
#
# File c:\Users\Maxparizot\anaconda3\Lib\site-packages\urllib3\util\ssl_.py:402, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     400 if ca_certs or ca_cert_dir or ca_cert_data:
#     401     try:
# --> 402         context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     403     except (IOError, OSError) as e:
#     404         raise SSLError(e)
#
# KeyboardInterrupt:
